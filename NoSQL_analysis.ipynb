# %% [markdown]
# # Eat Safe, Love
#
# This requires execution of NoSQL_setup.ipynb prior to using some of this code.

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": {"$eq":20}}

# Use count_documents to display the number of documents in the result
print("Number of establishments with hygiene score of 20: ", 
      establishments.count_documents(query), "\n")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of establishments with hygiene score of 20:  41
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64edec66682ca8e030a08881'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene20 = list(establishments.find(query))
hygiene20_df = pd.DataFrame(hygiene20)

# Display the number of rows in the DataFrame
print(f"The number of rows in this dataframe are {len(hygiene20_df)}\n")

# Display the first 10 rows of the DataFrame
hygiene20_df.head(10)
# Out:
# The number of rows in this dataframe are 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64edec66682ca8e030a08881   110681                  0
# 1  64edec66682ca8e030a08c06   612039                  0
# 2  64edec66682ca8e030a08f0c   730933                  0
# 3  64edec66682ca8e030a090fe   172735                  0
# 4  64edec66682ca8e030a0910c   172953                  0
# 5  64edec66682ca8e030a09aae   512854                  0
# 6  64edec66682ca8e030a09cca  1537089                  0
# 7  64edec66682ca8e030a0b1fa   155648                  0
# 8  64edec66682ca8e030a0b639  1012883                  0
# 9  64edec66682ca8e030a0be49   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?
#
# This requires execution of NoSQL_setup.ipynb prior as the setup file converted the RatingValue to an Integer.

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName":{"$regex":"London"}, "RatingValue":{"$gte":4}}

# Use count_documents to display the number of documents in the result
print("Number of London Local Authority establishments with Rating Value >= 4: ", 
      establishments.count_documents(query), "\n")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of London Local Authority establishments with Rating Value >= 4:  33
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64edec66682ca8e030a0a29f'),
# ...

# %%
# Convert the result to a Pandas DataFrame
london_rv4 = list(establishments.find(query))
london_rv4_df = pd.DataFrame(london_rv4)

# Display the number of rows in the DataFrame
print(f"The number of rows in this dataframe are {len(london_rv4_df)}\n")

# Display the first 10 rows of the DataFrame
london_rv4_df.head(10)
# Out:
# The number of rows in this dataframe are 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64edec66682ca8e030a0a29f   621707                  0
# 1  64edec66682ca8e030a0a5c6  1130836                  0
# 2  64edec66682ca8e030a0b115   293783                  0
# 3  64edec66682ca8e030a0bf10   294474                  0
# 4  64edec66682ca8e030a0bf1b  1315095                  0
# 5  64edec66682ca8e030a0c61f   294900                  0
# 6  64edec67682ca8e030a0e72b   293756                  0
# 7  64edec67682ca8e030a0eaef   878523                  0
# 8  64edec67682ca8e030a0eb0b   294606                  0
# 9  64edec67682ca8e030a0eb0d   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?
#
# This requires execution of NoSQL_setup.ipynb prior as the setup file converted the RatingValue to an Integer and latitude, longitude to doubles.

# %%
# Search within 0.01 degree on either side of the latitude and longitude of Penang Flavours.

# References used for $geoWithin
# https://stackoverflow.com/questions/25734092/query-locations-within-a-radius-in-mongodb
# https://www.mongodb.com/docs/manual/reference/operator/query/geoWithin/#mongodb-query-op.-geoWithin
# https://www.mongodb.com/docs/manual/reference/operator/query/centerSphere/#mongodb-query-op.-centerSphere

# Setup parameters for $geoWithin query
degree_search = 0.01
# Get the latitiude of Penang Flavours
pf_latitude_dict = establishments.find_one({"BusinessName":"Penang Flavours"}, {"geocode.latitude":1})
latitude = pf_latitude_dict["geocode"]["latitude"]
# Get the longitude of Penang Flavours
pf_longitude_dict = establishments.find_one({"BusinessName":"Penang Flavours"}, {"geocode.longitude":1})
longitude = pf_longitude_dict["geocode"]["longitude"]

# Define the query with the location requirements as well as the following
# -Rating value must equal 5
# -Hygiene score must be present (not None)
# -Excluding Penang Flavours

query = {"RatingValue":{"$eq":5},
         "geocode":{"$geoWithin":{"$centerSphere":[[longitude, latitude], degree_search]}},
         "scores.Hygiene":{"$ne":None},
         "BusinessName":{"$ne":"Penang Flavours"}
        }

# Optionally reduce fields for debug activity
# fields = {"AddressLine1":1, "AddressLine2":1, "AddressLine3":1, "AddressLine4":1, 
#           "BusinessName":1, "BusinessType": 1, "LocalAuthorityName":1, 
#           "RatingDate":1, "RatingKey":1, "RatingValue":1, 
#           "geocode":1, "scores":1}

# Sort by hygiene score
sort =  [("scores.Hygiene",1)]

# Get top 5 only
limit = 5

# Store the query in a variable
top5_by_PF = list(establishments.find(query).sort(sort).limit(limit))

# Print the results
print(f"Top results within 0.01 degrees of Penang Flavours (long {longitude}, lat {latitude})")
pprint(top5_by_PF)
# Out:
# Top results within 0.01 degrees of Penang Flavours (long 0.08384, lat 51.490142)
# [{'AddressLine1': 'Goldwyn School',
#   'AddressLine2': 'Godinton Lane',
#   'AddressLine3': 'Hothfield',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'Nourish at Goldwyn School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4608.101084149404,
#   'FHRSID': 802508,
#   'LocalAuthorityBusinessID': 'PI/000088893',
#   'LocalAuthorityCode': '179',
#   'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#   'LocalAuthorityName': 'Ashford',
#   'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'TN23 3BT',
#   'RatingDate': '2021-07-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64edec66682ca8e030a0814d'),
# ...

# %%
# Convert result to Pandas DataFrame
print(f"Top results within 0.01 degrees of Penang Flavours (long {longitude}, lat {latitude})")
top5_by_PF_df = pd.DataFrame(top5_by_PF)
top5_by_PF_df
# Out:
# Top results within 0.01 degrees of Penang Flavours (long 0.08384, lat 51.490142)
#                         _id   FHRSID  ChangesByServerID  \
# 0  64edec66682ca8e030a0814d   802508                  0
# 1  64edec66682ca8e030a081f9  1159449                  0
# 2  64edec66682ca8e030a08221   264696                  0
# 3  64edec66682ca8e030a0821b   682540                  0
# 4  64edec66682ca8e030a081a5   942989                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000088893            Nourish at Goldwyn School
# 1             PI/000096544  Principals, Challock Primary School
# 2             PI/000024292                 Challock Post Office
# 3             PI/000085559         The Barn Shop (Challock) Ltd
# 4             PI/000091820                              @Tony's
#
#                 BusinessType  BusinessTypeID                    AddressLine1  \
# 0  School/college/university            7845                  Goldwyn School
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {"$match": {"scores.Hygiene":0}}

# 2. Groups the matches by Local Authority
group_query = {"$group":{"_id":"$LocalAuthorityName", "count":{"$sum":1}}}

# 3. Sorts the matches from highest to lowest
sort_values = {"$sort":{"count":-1}}

# Put the query together and execute
hygiene0_pipeline = [match_query, group_query, sort_values]
hygiene0_results = list(establishments.aggregate(hygiene0_pipeline))

# Print the number of documents in the result
print(f"The number of Local Authorities that have establishments with a Hygiene score of 0 are {len(hygiene0_results)}\n")
# print(f"The total number of establishments with a Hygiene score of 0 are {}")

# Print the first 10 results
print("The first 10 results are:")
pprint(hygiene0_results[:10])
# Out:
# The number of Local Authorities that have establishments with a Hygiene score of 0 are 55
#
# The first 10 results are:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene0_df = pd.DataFrame(hygiene0_results)

# Display the number of rows in the DataFrame
print(f"There are {len(hygiene0_df)} rows in the DataFrame:")

# Display the first 10 rows of the DataFrame
hygiene0_df.head(10)
# Out:
# There are 55 rows in the DataFrame:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
